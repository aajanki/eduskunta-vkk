# %% [markdown]
# # Training a baseline classifier
#
# Train a simple baseline classifier for predicting the sentence class in the eduskunta-vkk data.
#
# See the [README](../README.md) for a description of the dataset.

# %%
# %matplotlib inline

import re
import libvoikko
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, make_scorer, roc_auc_score,\
    confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MaxAbsScaler, LabelEncoder
from sklearn.svm import LinearSVC, SVC

# %%
plt.rcParams["figure.figsize"] = (20, 10)

# %%
split_whitespace_re = re.compile(r"(?u)\b\w\w+\b")

def get_pipeline(n_dim=500, classifier='svc', reducer=None):
    vectorizer = TfidfVectorizer(tokenizer=tokenizer,
                                 ngram_range=(1, 2),
                                 max_df=0.1,
                                 stop_words=stop_words_fi)
    steps = [('vectorizer', vectorizer)]
    
    if reducer == 'svd':
        steps.append(('dimensionality_reduction', TruncatedSVD(n_dim)))
    elif reducer == 'chi2':
        steps.append(('dimensionality_reduction', SelectKBest(chi2, k=n_dim)))
    elif reducer:
        assert False, 'Unknown reducer'

    steps.append(('scaler', MaxAbsScaler()))

    if classifier == 'logreg':
        steps.append(('classifier', LogisticRegression(multi_class='multinomial', max_iter=1000)))
    elif classifier == 'svc':
        steps.append(('classifier', LinearSVC(loss='hinge', intercept_scaling=5.0,
                                              max_iter=100000, multi_class='ovr')))
    elif classifier:
        assert False, 'Unknown classifier'
    
    return Pipeline(steps)

def build_voikko_tokenizer(voikko):
    def tokenizer(text):
        tokens = []
        for w in split_whitespace_re.findall(text):
            analyzed = voikko.analyze(w)

            if analyzed:
                token = analyzed[0].get('BASEFORM', w)
            else:
                token = w

            tokens.append(token.lower())

        return tokens

    return tokenizer


voikko = libvoikko.Voikko('fi')
tokenizer = build_voikko_tokenizer(voikko)
stop_words_fi = list(set(tokenizer(t)[0] for t in [
    'ei', 'että', 'he', 'hän', 'ja', 'joka', 'jos', 'koska', 'kuin', 'kuka',
    'kun', 'me', 'mikä', 'minä', 'myös', 'ne', 'nuo', 'nämä', 'olla', 'se',
    'sinä', 'tai', 'te', 'tuo', 'tämä', 'vai',
]))

# %% [markdown]
# ## Load data

# %%
def load_documents(filename):
    return pd.read_csv(filename, header=0).rename(columns={'ministry': 'class'})

def load_data():
    train = load_documents('../vkk/train.csv.bz2')
    dev = load_documents('../vkk/dev.csv.bz2')
    test = load_documents('../vkk/test.csv.bz2')
    
    return train, dev, test

# %%
train, dev, test = load_data()
print(f'Number of train samples: {len(train)}')
print(f'Number of dev samples: {len(dev)}')
print(f'Number of test samples: {len(test)}')
# Out:
# Number of train samples: 49106
# Number of dev samples: 3000
# Number of test samples: 3000

# %%
short_names = {
    'perhe- ja peruspalveluministeri': 'per',
    'maatalous- ja ympäristöministeri': 'maa',
    'sisäministeri': 'sis',
    'oikeus- ja työministeri': 'oik',
    'opetus- ja kulttuuriministeri': 'ope',
    'valtiovarainministeri': 'val',
    'liikenne- ja viestintäministeri': 'lii',
    'sosiaali- ja terveysministeri': 'sos',
    'elinkeinoministeri': 'eli',
    'ulkoministeri': 'ulk',
    'kunta- ja uudistusministeri': 'kun',
    'eurooppa-, kulttuuri- ja urheiluministeri': 'eur',
    'pääministeri': 'pää',
    'puolustusministeri': 'puo',
    'ulkomaankauppa- ja kehitysministeri': 'uke',
}

# %% [markdown]
# ## Explore tokens that separate one class from the others

# %%
count_vectorizer = CountVectorizer(tokenizer=tokenizer, min_df=10, stop_words=stop_words_fi)
counts = count_vectorizer.fit_transform(train['sentence'], train['class'])

# %%
def get_discriminating_indexes(k, counts, count_vectorizer):
    res = {}
    for c in train['class'].unique():
        y = train['class'] == c
        scores, _ = chi2(counts, y)
        res[c] = np.argsort(-scores)[:k]

    return res

def print_discriminating_words(k, counts, count_vectorizer):
    discriminating = get_discriminating_indexes(k, counts, count_vectorizer)
    word_frequencies = counts.sum(axis=0)
    tokens = count_vectorizer.get_feature_names()
    for class_name, inds in discriminating.items():
        print(class_name)
        print('-'*30)
        print('\n'.join(f'{tokens[i]} ({word_frequencies[0, i]})' for i in inds))
        print()

print_discriminating_words(20, counts, count_vectorizer)
# Out:
# sisäministeri
# ------------------------------
# poliisi (838)
# maahanmuuttovirasto (421)
# sisäministeriö (290)
# turvapaikanhakija (416)
# ulkomaalaislaki (180)
# vastaanottokeskus (260)
# suojelu (477)
# poliisihallitus (141)
# oleskelulupa (255)
# poliisilaitos (116)
# hakija (547)
# ulkomaalainen (202)
# turvapaikka (130)
# palauttaa (176)
# turvapaikkahakemus (91)
# poliisimies (61)
# rajavartiolaitos (91)
# maahantulo (73)
# kansainvälistää (218)
# irak (104)
#
# oikeus- ja työministeri
# ------------------------------
# työnhakija (263)
# oikeusministeriö (318)
# velallinen (161)
# palkkatuki (128)
# työtön (282)
# työllistyä (322)
# työ (1683)
# toimisto (204)
# rikoslaki (166)
# työttömyysetuus (264)
# henkilötieto (116)
# käräjäoikeus (86)
# palkkatuettu (60)
# yritystoiminta (203)
# suojaosuus (59)
# rangaistava (104)
# työvoima (163)
# törkeä (87)
# luku (555)
# elinkeinotoimisto (91)
#
# maatalous- ja ympäristöministeri
# ------------------------------
# metsätalousministeriö (310)
# eläin (327)
# metsähallitus (228)
# metsä (177)
# metsästys (175)
# susi (161)
# ympäristöministeriö (206)
# laji (162)
# elintarvike (196)
# vahinko (235)
# maatalous (136)
# kalastus (94)
# koira (167)
# itämeri (124)
# luonnonvarakeskus (81)
# metsätalous (91)
# poikkeuslupa (106)
# hehtaari (72)
# riistakeskus (67)
# maa (1536)
#
# perhe- ja peruspalveluministeri
# ------------------------------
# terveydenhuolto (870)
# sosiaali (1272)
# hoito (1056)
# palvelu (2364)
# potilas (455)
# asiakas (957)
# sosiaalihuolto (216)
# iäkäs (163)
# kela (360)
# terveysministeriö (632)
# thl (149)
# toimeentulotuki (297)
# sairaanhoitopiiri (152)
# kunta (1678)
# omaishoito (116)
# hyvinvointi (498)
# lastensuojelu (116)
# sosiaalihuoltolaki (99)
# terveys (533)
# ammattihenkilö (199)
#
# sosiaali- ja terveysministeri
# ------------------------------
# lääke (443)
# kansaneläkelaitos (486)
# sairausvakuutuslaki (153)
# työkyvyttömyyseläke (103)
# aktiivimalli (65)
# vakuutettu (104)
# alkuomavastuu (61)
# apteekki (86)
# sairaus (310)
# kuntoutus (389)
# etuus (278)
# lääkehoito (134)
# omavastuu (45)
# eläke (73)
# korvattava (100)
# terveysministeriö (632)
# sairausvakuutus (79)
# lääkekatto (38)
# korvattavuus (53)
# työttömyyskassa (48)
#
# opetus- ja kulttuuriministeri
# ------------------------------
# opetus (1067)
# koulutus (1613)
# varhaiskasvatus (548)
# ammatillinen (638)
# yliopisto (532)
# opiskelija (688)
# kulttuuriministeriö (514)
# järjestäjä (382)
# perusopetus (286)
# korkeakoulu (302)
# ammattikorkeakoulu (270)
# oppilas (235)
# tutkinto (339)
# varhaiskasvatuslaki (150)
# koulu (319)
# osata (660)
# oppia (161)
# opettaja (169)
# opetushallitus (126)
# opetussuunnitelma (158)
#
# eurooppa-, kulttuuri- ja urheiluministeri
# ------------------------------
# tuloraja (56)
# taide (117)
# museo (31)
# erikoismuseo (18)
# tekijänoikeus (55)
# museovirasto (40)
# nuorisoala (15)
# liikunta (88)
# urheilu (39)
# opintotuki (83)
# taiteilija (59)
# musiikki (35)
# kirjasto (26)
# esittävä (18)
# kulttuuriministeriö (514)
# työpaja (19)
# luovi (23)
# teos (23)
# museolaki (10)
# nuorisolaki (18)
#
# liikenne- ja viestintäministeri
# ------------------------------
# liikenne (755)
# viestintäministeriö (225)
# liikennevirasto (115)
# ajoneuvo (255)
# maantie (83)
# rata (84)
# viestintävirasto (90)
# postilaki (65)
# yleisradio (58)
# ajokortti (51)
# tasoristeys (46)
# palvelutaso (78)
# hanko (42)
# nopeusrajoitus (41)
# rataosa (51)
# vr (217)
# tie (134)
# liikenneturvallisuus (58)
# tieliikennelaki (41)
# kuljettaja (75)
#
# ulkoministeri
# ------------------------------
# yk (200)
# turkki (61)
# libya (40)
# sahara (31)
# suomia (708)
# marokko (27)
# ihmisoikeus (113)
# eu (1252)
# länsi (45)
# päätöslauselma (29)
# venezuela (18)
# syyria (33)
# pakistan (15)
# suurlähetystö (32)
# bahrain (13)
# pääsihteeri (12)
# äänestys (16)
# ulkoministeri (16)
# edustusto (53)
# elinsiirto (12)
#
# pääministeri
# ------------------------------
# vr (217)
# yhtiö (466)
# posti (259)
# stream (18)
# lippu (73)
# nord (19)
# peruslippu (14)
# talousvyöhyke (15)
# junalippu (16)
# säästölippu (11)
# kioski (18)
# lipunmyynti (20)
# verkkokauppa (11)
# finnair (45)
# vapo (13)
# juna (48)
# maakohtainen (26)
# sairausaika (15)
# puhelinpalvelus (12)
# osoitteeton (23)
#
# valtiovarainministeri
# ------------------------------
# vero (294)
# verotus (252)
# verohallinto (163)
# verovelvollinen (119)
# verokanta (62)
# veropohja (45)
# auto (167)
# tuloverolaki (45)
# verottaa (50)
# vähennys (85)
# virtuaalivaluutta (33)
# valtiovarainministeriö (149)
# yleishyödyllinen (63)
# vähennyskelpoinen (32)
# verotusarvo (34)
# virvoitusjuomavero (30)
# kotitalousvähennys (39)
# verovapaa (29)
# verokohtelu (38)
# tulorekisteri (61)
#
# elinkeinoministeri
# ------------------------------
# sähkö (180)
# finpron (44)
# kaivostoiminta (71)
# kaivoslaki (50)
# kaivos (48)
# yhtiö (466)
# esir (36)
# posti (259)
# energia (163)
# fortum (48)
# raskoneen (23)
# terrafame (25)
# finland (77)
# markkina (285)
# uusiutuva (104)
# sähköntuotanto (23)
# team (46)
# tehoreservi (16)
# stuk (35)
# pk (55)
#
# kunta- ja uudistusministeri
# ------------------------------
# maistraatti (63)
# väestötietojärjestelmä (54)
# koordinaatioryhmä (36)
# alueellistaa (36)
# senaatti (46)
# kuntalaki (32)
# kiinteistövarallisuus (24)
# valtuusto (17)
# koulunkäyntiavustaja (11)
# arviointimenettely (27)
# muuttopäivä (14)
# postilaatikko (16)
# valtio (1434)
# kunta (1678)
# palvelukeskus (24)
# muuttoilmoitus (16)
# valtionosuusjärjestelmä (21)
# asiointipiste (10)
# jakamistalous (10)
# kuollut (32)
#
# puolustusministeri
# ------------------------------
# puolustusvoima (150)
# mpk (32)
# varusmies (41)
# maanpuolustus (33)
# harjoitustoiminta (32)
# sotilaallinen (59)
# nato (30)
# vientilupa (27)
# varusmiespalvelus (23)
# puolustus (21)
# puolustusministeriö (32)
# maanpuolustuskoulutusyhdistys (14)
# palvelus (114)
# pääesikunta (15)
# asevelvollinen (23)
# ilmavoima (13)
# turvallisuuskomitea (12)
# kutsunta (10)
# harjoitus (39)
# diabeetikko (29)
#
# ulkomaankauppa- ja kehitysministeri
# ------------------------------
# kehitysyhteistyö (64)
# finnfundin (32)
# finnfund (28)
# kansalaisjärjestö (67)
# humanitaarinen (93)
# kehitysmaa (20)
# ulkoministeriö (52)
# honduras (14)
# unrwa (14)
# palestiinalaishallinto (17)
# kehityspolitiikka (21)
# globaalikasvatus (14)
# ulkoasiainministeriö (54)
# järjestö (266)
# tyttö (71)
# israel (38)
# opetussektori (10)
# kehityspoliittinen (24)
# miinatoiminta (11)
# lisääntymisterveys (39)

# %% [markdown]
# ## Train a classifier
#
# Train a linear SVM. Learn the SVM regularization parameter by cross-validation on the training set. The multiclass predictions are summarized by a weighted F1 score.

# %%
grid = {'classifier__C': [1e-2, 1e-1, 1]}
pipe = get_pipeline(classifier='svc')

enc = LabelEncoder()
y_encoded = enc.fit_transform(train['class'])

gridsearch = GridSearchCV(pipe, grid, cv=5, scoring='f1_weighted', refit=True, n_jobs=1, verbose=2)
gridsearch.fit(train['sentence'], y_encoded)
clf = gridsearch.best_estimator_

gridsearch.cv_results_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] classifier__C=0.01 ..............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................... classifier__C=0.01, total=  33.0s
# [CV] classifier__C=0.01 ..............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   33.1s remaining:    0.0s
# [CV] ............................... classifier__C=0.01, total=  32.9s
# [CV] classifier__C=0.01 ..............................................
# [CV] ............................... classifier__C=0.01, total=  33.7s
# [CV] classifier__C=0.01 ..............................................
# [CV] ............................... classifier__C=0.01, total=  32.6s
# [CV] classifier__C=0.01 ..............................................
# [CV] ............................... classifier__C=0.01, total=  34.1s
# [CV] classifier__C=0.1 ...............................................
# [CV] ................................ classifier__C=0.1, total=  43.8s
# [CV] classifier__C=0.1 ...............................................
# [CV] ................................ classifier__C=0.1, total=  45.7s
# [CV] classifier__C=0.1 ...............................................
# [CV] ................................ classifier__C=0.1, total=  46.0s
# [CV] classifier__C=0.1 ...............................................
# [CV] ................................ classifier__C=0.1, total=  46.7s
# [CV] classifier__C=0.1 ...............................................
# [CV] ................................ classifier__C=0.1, total=  40.8s
# [CV] classifier__C=1 .................................................
# [CV] .................................. classifier__C=1, total= 1.1min
# [CV] classifier__C=1 .................................................
# [CV] .................................. classifier__C=1, total= 1.3min
# [CV] classifier__C=1 .................................................
# [CV] .................................. classifier__C=1, total= 1.2min
# [CV] classifier__C=1 .................................................
# [CV] .................................. classifier__C=1, total= 1.1min
# [CV] classifier__C=1 .................................................
# [CV] .................................. classifier__C=1, total= 1.2min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 12.4min finished
# {'mean_fit_time': array([28.72737432, 40.11144671, 66.30900669]),
#  'std_fit_time': array([0.4453742 , 2.11377787, 2.58572886]),
#  'mean_score_time': array([4.53586855, 4.49978962, 4.44117928]),
#  'std_score_time': array([0.17089665, 0.04175988, 0.03575632]),
#  'param_classifier__C': masked_array(data=[0.01, 0.1, 1],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'classifier__C': 0.01},
#   {'classifier__C': 0.1},
#   {'classifier__C': 1}],
#  'split0_test_score': array([0.67913941, 0.70862327, 0.69616344]),
#  'split1_test_score': array([0.6765328 , 0.70936675, 0.69887373]),
#  'split2_test_score': array([0.68204752, 0.71596557, 0.70157058]),
#  'split3_test_score': array([0.68477533, 0.71671198, 0.7030204 ]),
#  'split4_test_score': array([0.68385035, 0.71561636, 0.69835516]),
#  'mean_test_score': array([0.68126908, 0.71325679, 0.69959666]),
#  'std_test_score': array([0.00305059, 0.00350558, 0.00242773]),
#  'rank_test_score': array([3, 1, 2], dtype=int32)}

# %% [markdown]
# ## Evaluation on the test set

# %%
X_test = test['sentence']
y_test_true = test['class']
y_test_pred = enc.inverse_transform(clf.predict(X_test))

print(classification_report(y_test_true, y_test_pred))
# Out:
#                                            precision    recall  f1-score   support
#
#                        elinkeinoministeri       0.63      0.50      0.56       104
# eurooppa-, kulttuuri- ja urheiluministeri       0.72      0.61      0.66        51
#               kunta- ja uudistusministeri       0.66      0.38      0.48        56
#           liikenne- ja viestintäministeri       0.77      0.77      0.77       231
#          maatalous- ja ympäristöministeri       0.77      0.83      0.80       450
#                   oikeus- ja työministeri       0.64      0.68      0.66       362
#             opetus- ja kulttuuriministeri       0.80      0.82      0.81       348
#           perhe- ja peruspalveluministeri       0.68      0.76      0.71       480
#                        puolustusministeri       0.83      0.64      0.72        39
#                              pääministeri       0.63      0.48      0.55        54
#                             sisäministeri       0.71      0.78      0.75       336
#             sosiaali- ja terveysministeri       0.76      0.62      0.68       215
#       ulkomaankauppa- ja kehitysministeri       0.87      0.70      0.78        37
#                             ulkoministeri       0.86      0.63      0.73        76
#                     valtiovarainministeri       0.78      0.70      0.74       161
#
#                                  accuracy                           0.73      3000
#                                 macro avg       0.74      0.66      0.69      3000
#                              weighted avg       0.73      0.73      0.73      3000

# %%
display_labels = [short_names[x] for x in enc.inverse_transform(clf.classes_)]
cm = confusion_matrix(y_test_true, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.show()
